# %% [markdown]
# # Create nba datasets

# %% [markdown]
# ## Setup and imports

# %%
import jsonlines
import pandas as pd

# %%
pd.options.display.max_columns = 99
pd.options.display.max_rows = 99

# %% [markdown]
# ## Read datasets from jsonlines files

# %%
seasons_df = pd.read_json("./season.jl", lines=True)

# %%
games_df = pd.read_json("./game.jl", lines=True)

# %%
players_df = pd.read_json("./player.jl", lines=True)

# %%
boxscores_file = "./boxscore.jl"
with jsonlines.open(boxscores_file) as reader:
    basic_boxscores_df = pd.DataFrame(
        list(filter(lambda x: x.get('boxscore')=='basic', iter(reader)))
    )

# %%
with jsonlines.open(boxscores_file) as reader:
    advanced_boxscores_df = pd.DataFrame(
        list(filter(lambda x: x.get('boxscore')=='advanced', iter(reader)))
    )

# %% [markdown]
# ## Clean data

# %% [markdown]
# Type conversions

# %%
def convert_dtypes(data):
    for col in data:
        try:
            data[col] = data[col].astype(float)
        except ValueError:
            pass
        except TypeError:
            pass
    return data

# %%
basic_boxscores_df = convert_dtypes(basic_boxscores_df)
advanced_boxscores_df = convert_dtypes(advanced_boxscores_df)
games_df = convert_dtypes(games_df)
seasons_df = convert_dtypes(seasons_df)
players_df = convert_dtypes(players_df)

# %% [markdown]
# Fix links

# %%
def fix_link(data, column):
    root = "https://www.basketball-reference.com"
    data[column] = root + data[column].str.replace(root, "")
    return data

# %%
basic_boxscores_df = basic_boxscores_df.pipe(fix_link, "player_link")
advanced_boxscores_df = advanced_boxscores_df.pipe(fix_link, "player_link")
seasons_df = seasons_df.pipe(fix_link, "season_link")
players_df = players_df.pipe(fix_link, "player_link")
games_df = (
    games_df
        .pipe(fix_link, "boxscore_link")
        .pipe(fix_link, "home_link")
        .pipe(fix_link, "visitor_link")
)

# %% [markdown]
# Update mp to fraction

# %%
def minutes_string_to_float(series):
    return (
        series
         .str.split(":", expand=True)
         .apply(lambda x: x.astype(float))
         .rename(columns = {0: "mins", 1: "secs"})
         .eval('mins + secs/60')
    )

# %%
basic_boxscores_df['minutes'] = minutes_string_to_float(basic_boxscores_df.mp)
advanced_boxscores_df['minutes'] = minutes_string_to_float(advanced_boxscores_df.mp)

# %% [markdown]
# Stack home and away games data

# %%
home_games = games_df[['attendance', 'boxscore_link', 'date', 'home', 'home_link', 'home_pts',
       'notes', 'overtime', 'season_link', 'start']].copy()
home_games['location'] = 'home'
home_games = home_games.rename(columns={'home': 'team', 'home_link': 'team_link', 'home_pts': 'pts'})

# %%
visitor_games = games_df[['attendance', 'boxscore_link', 'date', 'visitor', 'visitor_link', 'visitor_pts',
       'notes', 'overtime', 'season_link', 'start']].copy()
visitor_games['location'] = 'away'
visitor_games = visitor_games.rename(columns={'visitor': 'team', 'visitor_link': 'team_link', 'visitor_pts': 'pts'})

# %%
normalized_games_df = pd.concat([home_games, visitor_games], ignore_index=True)

# %% [markdown]
# Identify playoff games

# %%
def game_number(data):
    return (
        data
        .groupby(['season_link', 'team'])
        ['date'].rank()
    )

def team_game_count(data):
    return (
        data
        .eval("counter = 1")
        .groupby(['season_link', 'team'])
        ['counter'].transform('count')
    )

def min_team_games(data):
    return (
        data
        .groupby(['season_link'])
        ['team_game_count'].transform('min')
    )

# %%
normalized_games_df['playoffs'] = (
    normalized_games_df
     .assign(game_number=game_number)
     .assign(team_game_count=team_game_count)
     .assign(min_team_games=min_team_games)
     .eval('game_number > min_team_games')
)

# %% [markdown]
# ## Data quality checks

# %% [markdown]
# Confirm that games in basic boxscores matches games in game summaries

# %%
len(games_df.boxscore_link.unique()) == len(games_df.boxscore_link)
# Out:
# True

# %%
len(basic_boxscores_df.game_url.unique()), len(games_df.boxscore_link.unique())
# Out:
# (67093, 67094)

# %%
games_df[~(games_df.boxscore_link).isin(basic_boxscores_df.game_url.unique())]
# Out:
#       attendance                                      boxscore_link  \
# 52971      4,643  https://www.basketball-reference.com/boxscores...
#
#             date              home  \
# 52971 1972-10-26  Virginia Squires
#
#                                                home_link  home_pts  \
# 52971  https://www.basketball-reference.com/teams/VIR...       2.0
#
#                                  notes overtime  \
# 52971  at Richmond, VA; forfeit to VIR     None
#
#                                              season_link start  \
# 52971  https://www.basketball-reference.com/leagues/A...  None
#
#               visitor                                       visitor_link  \
# 52971  Denver Rockets  https://www.basketball-reference.com/teams/DNR...
#
#        visitor_pts
# 52971          0.0

# %% [markdown]
# Confirm that the number of points in boxscore match number of points in games

# %%
total_points = (
    basic_boxscores_df
        .groupby('game_url')['pts']
        .sum()
)

# %%
total_points_game = (
    games_df
        .rename(columns={'boxscore_link': 'game_url'})
        .assign(total_pts = lambda x: x.home_pts + x.visitor_pts)
        .merge(total_points.reset_index(),
            how='outer',
            on='game_url'
        )
)

# %%
(total_points_game
     .assign(mismatch = lambda x: x.total_pts - x.pts)
     .assign(abs_mismatch = lambda x: abs(x.mismatch))
     .groupby('season_link')['mismatch', 'abs_mismatch']
     .aggregate('mean')
     .query('abs_mismatch != 0')
)
# Out:
#                                                     mismatch  abs_mismatch
# season_link
# https://www.basketball-reference.com/leagues/AB...  0.012987      0.012987
# https://www.basketball-reference.com/leagues/AB...  0.006369      0.006369
# https://www.basketball-reference.com/leagues/AB...  0.037849      0.065737
# https://www.basketball-reference.com/leagues/AB...  0.029821      0.029821
# https://www.basketball-reference.com/leagues/AB... -0.001988      0.013917
# https://www.basketball-reference.com/leagues/AB...  0.008734      0.039301
# https://www.basketball-reference.com/leagues/AB...  0.004357      0.021786
# https://www.basketball-reference.com/leagues/AB...  0.004348      0.004348
# https://www.basketball-reference.com/leagues/BA...  0.005714      0.005714
# https://www.basketball-reference.com/leagues/BA...  0.074419      0.074419
# https://www.basketball-reference.com/leagues/NB...  0.020236      0.020236
# https://www.basketball-reference.com/leagues/NB...  0.044737      0.044737
# https://www.basketball-reference.com/leagues/NB...  0.005634      0.005634
# https://www.basketball-reference.com/leagues/NB...  0.018717      0.077540
# https://www.basketball-reference.com/leagues/NB...  0.072046      0.083573
# https://www.basketball-reference.com/leagues/NB...  0.391586      0.398058
# https://www.basketball-reference.com/leagues/NB...  0.061093      0.061093
# https://www.basketball-reference.com/leagues/NB...  0.006515      0.006515
# https://www.basketball-reference.com/leagues/NB... -0.006472      0.006472
# https://www.basketball-reference.com/leagues/NB...  0.029032      0.151613
# https://www.basketball-reference.com/leagues/NB... -0.073846      0.166154
# https://www.basketball-reference.com/leagues/NB... -0.005865      0.123167
# https://www.basketball-reference.com/leagues/NB... -0.010283      0.051414
# https://www.basketball-reference.com/leagues/NB... -0.059126      0.125964
# https://www.basketball-reference.com/leagues/NB... -0.005181      0.005181
# https://www.basketball-reference.com/leagues/NB... -0.010336      0.010336
# https://www.basketball-reference.com/leagues/NB... -0.003759      0.003759
# https://www.basketball-reference.com/leagues/NB...  0.029364      0.029364
# https://www.basketball-reference.com/leagues/NB...  0.002725      0.002725
# https://www.basketball-reference.com/leagues/NB... -0.002710      0.002710
# https://www.basketball-reference.com/leagues/NB... -0.018970      0.018970
# https://www.basketball-reference.com/leagues/NB... -0.005096      0.005096
# https://www.basketball-reference.com/leagues/NB... -0.005236      0.005236
# https://www.basketball-reference.com/leagues/NB...  0.008421      0.008421
# https://www.basketball-reference.com/leagues/NB... -0.003030      0.003030
# https://www.basketball-reference.com/leagues/NB...  0.006085      0.006085

# %% [markdown]
# Check total number of games in a season

# %%
(normalized_games_df
     .groupby(['season_link', 'team'])['boxscore_link']
     .count()
     .groupby(['season_link'])
     .aggregate(["max", "min"])
     .eval("diff = max - min")
)
# Out:
#                                                     max  min  diff
# season_link
# https://www.basketball-reference.com/leagues/AB...   95   78    17
# https://www.basketball-reference.com/leagues/AB...   95   78    17
# https://www.basketball-reference.com/leagues/AB...  101   84    17
# https://www.basketball-reference.com/leagues/AB...  103   84    19
# https://www.basketball-reference.com/leagues/AB...  104   84    20
# https://www.basketball-reference.com/leagues/AB...  103   84    19
# https://www.basketball-reference.com/leagues/AB...  102   84    18
# https://www.basketball-reference.com/leagues/AB...  102   84    18
# https://www.basketball-reference.com/leagues/AB...   97   11    86
# https://www.basketball-reference.com/leagues/BA...   72   60    12
# https://www.basketball-reference.com/leagues/BA...   61   48    13
# https://www.basketball-reference.com/leagues/BA...   71   60    11
# https://www.basketball-reference.com/leagues/NB...   81   62    19
# https://www.basketball-reference.com/leagues/NB...   82   35    47
# https://www.basketball-reference.com/leagues/NB...   80   66    14
# https://www.basketball-reference.com/leagues/NB...   82   69    13
# https://www.basketball-reference.com/leagues/NB...   85   72    13
# https://www.basketball-reference.com/leagues/NB...   83   72    11
# https://www.basketball-reference.com/leagues/NB...   82   72    10
# https://www.basketball-reference.com/leagues/NB...   84   72    12
# https://www.basketball-reference.com/leagues/NB...   83   72    11
# https://www.basketball-reference.com/leagues/NB...   85   72    13
# https://www.basketball-reference.com/leagues/NB...   89   75    14
# https://www.basketball-reference.com/leagues/NB...   91   79    12
# https://www.basketball-reference.com/leagues/NB...   94   80    14
# https://www.basketball-reference.com/leagues/NB...   93   80    13
# https://www.basketball-reference.com/leagues/NB...   92   80    12
# https://www.basketball-reference.com/leagues/NB...   92   80    12
# https://www.basketball-reference.com/leagues/NB...   97   80    17
# https://www.basketball-reference.com/leagues/NB...   96   81    15
# https://www.basketball-reference.com/leagues/NB...  101   82    19
# https://www.basketball-reference.com/leagues/NB...  100   82    18
# https://www.basketball-reference.com/leagues/NB...  101   82    19
# https://www.basketball-reference.com/leagues/NB...  100   82    18
# https://www.basketball-reference.com/leagues/NB...   98   82    16
# https://www.basketball-reference.com/leagues/NB...   99   82    17
# https://www.basketball-reference.com/leagues/NB...  100   82    18
# https://www.basketball-reference.com/leagues/NB...   99   82    17
# https://www.basketball-reference.com/leagues/NB...  101   82    19
# https://www.basketball-reference.com/leagues/NB...  101   82    19
# https://www.basketball-reference.com/leagues/NB...  104   82    22
# https://www.basketball-reference.com/leagues/NB...  101   82    19
# https://www.basketball-reference.com/leagues/NB...  100   82    18
# https://www.basketball-reference.com/leagues/NB...  103   82    21
# https://www.basketball-reference.com/leagues/NB...  103   82    21
# https://www.basketball-reference.com/leagues/NB...   97   82    15
# https://www.basketball-reference.com/leagues/NB...  105   82    23
# https://www.basketball-reference.com/leagues/NB...  103   82    21
# https://www.basketball-reference.com/leagues/NB...  102   82    20
# https://www.basketball-reference.com/leagues/NB...  105   82    23
# https://www.basketball-reference.com/leagues/NB...  106   82    24
# https://www.basketball-reference.com/leagues/NB...   99   82    17
# https://www.basketball-reference.com/leagues/NB...  103   82    21
# https://www.basketball-reference.com/leagues/NB...  101   82    19
# https://www.basketball-reference.com/leagues/NB...  104   82    22
# https://www.basketball-reference.com/leagues/NB...  106   82    24
# https://www.basketball-reference.com/leagues/NB...  107   82    25
# https://www.basketball-reference.com/leagues/NB...  104   82    22
# https://www.basketball-reference.com/leagues/NB...  103   82    21
# https://www.basketball-reference.com/leagues/NB...  102   82    20
# https://www.basketball-reference.com/leagues/NB...  103   82    21
# https://www.basketball-reference.com/leagues/NB...   70   50    20
# https://www.basketball-reference.com/leagues/NB...  105   82    23
# https://www.basketball-reference.com/leagues/NB...  105   82    23
# https://www.basketball-reference.com/leagues/NB...  102   82    20
# https://www.basketball-reference.com/leagues/NB...  106   82    24
# https://www.basketball-reference.com/leagues/NB...  105   82    23
# https://www.basketball-reference.com/leagues/NB...  107   82    25
# https://www.basketball-reference.com/leagues/NB...  105   82    23
# https://www.basketball-reference.com/leagues/NB...  102   82    20
# https://www.basketball-reference.com/leagues/NB...  108   82    26
# https://www.basketball-reference.com/leagues/NB...  106   82    24
# https://www.basketball-reference.com/leagues/NB...  106   82    24
# https://www.basketball-reference.com/leagues/NB...  103   82    21
# https://www.basketball-reference.com/leagues/NB...   89   66    23
# https://www.basketball-reference.com/leagues/NB...  105   82    23
# https://www.basketball-reference.com/leagues/NB...  105   82    23
# https://www.basketball-reference.com/leagues/NB...  103   82    21
# https://www.basketball-reference.com/leagues/NB...  106   82    24
# https://www.basketball-reference.com/leagues/NB...  100   82    18
# https://www.basketball-reference.com/leagues/NB...  104   82    22

# %% [markdown]
# ## Save processed data as parquet files

# %%
seasons_df.to_parquet('data/season.parquet')
games_df.to_parquet('data/game.parquet')
players_df.to_parquet('data/player.parquet')
basic_boxscores_df.to_parquet('data/basic_boxscore.parquet')
advanced_boxscores_df.to_parquet('data/adv_boxscore.parquet')
normalized_games_df.to_parquet('data/normalized_games.parquet')
